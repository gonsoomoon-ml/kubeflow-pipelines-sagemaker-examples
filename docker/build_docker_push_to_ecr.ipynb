# %%
import boto3
sess = boto3.Session()

# %% [markdown]
# **Select a name for the ECR repository**

# %%
ecr_repo_name = 'sagemaker-kubernetes'

region = boto3.Session().region_name
account = boto3.client('sts').get_caller_identity().get('Account')
image = '{}.dkr.ecr.{}.amazonaws.com/{}:latest'.format(account, region, ecr_repo_name)

# %% [markdown]
# **Build a container image locally with training scripts**

# %%
# !$(aws ecr get-login --no-include-email --region us-west-2 --registry-ids 763104351884)
# !docker build -t {ecr_repo_name}:latest .
# Out:
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# Sending build context to Docker daemon   76.8kB
# Step 1/7 : FROM 763104351884.dkr.ecr.us-west-2.amazonaws.com/tensorflow-training:1.15.2-gpu-py36-cu100-ubuntu18.04
# 1.15.2-gpu-py36-cu100-ubuntu18.04: Pulling from tensorflow-training
#
# c47eeb70: Pulling fs layer
# dc448b72: Pulling fs layer
# 70e39044: Pulling fs layer
# 37916d57: Pulling fs layer
# 569ddae6: Pulling fs layer
# 2c57c41d: Pulling fs layer
# 04a00543: Pulling fs layer
# c90152db: Pulling fs layer
# 652ce645: Pulling fs layer
# 027e0082: Pulling fs layer
# 8168a55a: Pulling fs layer
# b219f0d1: Pulling fs layer
# 5a45ce9f: Pulling fs layer
# 04a00543: Waiting fs layer
# 335f456c: Pulling fs layer
# c90152db: Waiting fs layer
# 663c774b: Pulling fs layer
# 8168a55a: Waiting fs layer
# 27e0082: Waiting fs layer
# 69ddae6: Waiting fs layer
# 219f0d1: Waiting fs layer
# a0d3090d: Pull complete 266kB/4.266kBBDownloading  2.192MB/9.982MBDigest: sha256:98f6ad8fd3bc64fd37bc8844f9829a4487a6d78122252bd68ae654d8d3213e2e
# Status: Downloaded newer image for 763104351884.dkr.ecr.us-west-2.amazonaws.com/tensorflow-training:1.15.2-gpu-py36-cu100-ubuntu18.04
#  ---> d095fe2548aa
# Step 2/7 : RUN pip3 install sagemaker-training
#  ---> Running in 7aa2848fcf4d
# Collecting sagemaker-training
#   Downloading sagemaker_training-3.9.0.tar.gz (45 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from sagemaker-training) (1.18.3)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from sagemaker-training) (1.12.42)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sagemaker-training) (1.14.0)
# Requirement already satisfied: pip in /usr/local/lib/python3.6/dist-packages (from sagemaker-training) (20.0.2)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from sagemaker-training) (1.3.3)
# Requirement already satisfied: gevent in /usr/local/lib/python3.6/dist-packages (from sagemaker-training) (1.5.0)
# Requirement already satisfied: inotify_simple==1.2.1 in /usr/local/lib/python3.6/dist-packages (from sagemaker-training) (1.2.1)
# Requirement already satisfied: werkzeug>=0.15.5 in /usr/local/lib/python3.6/dist-packages (from sagemaker-training) (1.0.1)
# Requirement already satisfied: paramiko>=2.4.2 in /usr/local/lib/python3.6/dist-packages (from sagemaker-training) (2.7.1)
# Requirement already satisfied: psutil>=5.6.7 in /usr/local/lib/python3.6/dist-packages (from sagemaker-training) (5.7.0)
# Requirement already satisfied: protobuf>=3.1 in /usr/local/lib/python3.6/dist-packages (from sagemaker-training) (3.11.3)
# Requirement already satisfied: scipy>=1.2.2 in /usr/local/lib/python3.6/dist-packages (from sagemaker-training) (1.2.2)
# Requirement already satisfied: botocore<1.16.0,>=1.15.42 in /usr/local/lib/python3.6/dist-packages (from boto3->sagemaker-training) (1.15.42)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->sagemaker-training) (0.3.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->sagemaker-training) (0.9.5)
# Requirement already satisfied: greenlet>=0.4.14; platform_python_implementation == "CPython" in /usr/local/lib/python3.6/dist-packages (from gevent->sagemaker-training) (0.4.15)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.6/dist-packages (from paramiko>=2.4.2->sagemaker-training) (2.9.1)
# Requirement already satisfied: bcrypt>=3.1.3 in /usr/local/lib/python3.6/dist-packages (from paramiko>=2.4.2->sagemaker-training) (3.1.7)
# Requirement already satisfied: pynacl>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from paramiko>=2.4.2->sagemaker-training) (1.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.1->sagemaker-training) (46.1.3)
# Requirement already satisfied: urllib3<1.26,>=1.20; python_version != "3.4" in /usr/local/lib/python3.6/dist-packages (from botocore<1.16.0,>=1.15.42->boto3->sagemaker-training) (1.25.9)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.16.0,>=1.15.42->boto3->sagemaker-training) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.16.0,>=1.15.42->boto3->sagemaker-training) (2.8.1)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/dist-packages (from cryptography>=2.5->paramiko>=2.4.2->sagemaker-training) (1.14.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.5->paramiko>=2.4.2->sagemaker-training) (2.20)
# Building wheels for collected packages: sagemaker-training
#   Building wheel for sagemaker-training (setup.py): started
#   Building wheel for sagemaker-training (setup.py): finished with status 'done'
#   Created wheel for sagemaker-training: filename=sagemaker_training-3.9.0-cp36-cp36m-linux_x86_64.whl size=73336 sha256=455bfa036dc6303b50cfc30e053bd557f300c3332a3e6cdef05078ac18544753
#   Stored in directory: /root/.cache/pip/wheels/a0/14/84/e3805e5daa13fabab04c9aba0df0c636c2c8cfbf1f81c6553f
# Successfully built sagemaker-training
# Installing collected packages: sagemaker-training
# Successfully installed sagemaker-training-3.9.0
# WARNING: You are using pip version 20.0.2; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Removing intermediate container 7aa2848fcf4d
#  ---> 1de60700c811
# Step 3/7 : COPY cifar10-training-sagemaker.py /opt/ml/code/cifar10-training-sagemaker.py
#  ---> c09b34674d31
# Step 4/7 : COPY model_def.py /opt/ml/code/model_def.py
#  ---> 01a01ec90317
# Step 5/7 : COPY inference.py /opt/ml/model/code/inference.py
#  ---> f983cf686918
# Step 6/7 : COPY requirements.txt /opt/ml/model/code/requirements.txt
#  ---> be47a5c87836
# Step 7/7 : ENV SAGEMAKER_PROGRAM cifar10-training-sagemaker.py
#  ---> Running in 92d16c495075
# Removing intermediate container 92d16c495075
#  ---> 18caaa98e75b
# Successfully built 18caaa98e75b
# Successfully tagged sagemaker-kubernetes:latest

# %% [markdown]
# **Create an ECR repository if one doesn't exist**

# %%
# !aws ecr create-repository --repository-name {ecr_repo_name}
# Out:
# {
#     "repository": {
#         "repositoryArn": "arn:aws:ecr:ap-northeast-2:790639055451:repository/sagemaker-kubernetes",
#         "registryId": "790639055451",
#         "repositoryName": "sagemaker-kubernetes",
#         "repositoryUri": "790639055451.dkr.ecr.ap-northeast-2.amazonaws.com/sagemaker-kubernetes",
#         "createdAt": 1617887004.0,
#         "imageTagMutability": "MUTABLE",
#         "imageScanningConfiguration": {
#             "scanOnPush": false
#         },
#         "encryptionConfiguration": {
#             "encryptionType": "AES256"
#         }
#     }
# }

# %% [markdown]
# **Push image to ECR**

# %%
# !$(aws ecr get-login --no-include-email --region {region})
# !docker tag {ecr_repo_name}:latest {image}
# !docker push {image}
# Out:
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# The push refers to repository [790639055451.dkr.ecr.ap-northeast-2.amazonaws.com/sagemaker-kubernetes]
#
# f49a79ba: Preparing
# 92ad4d1b: Preparing
# 39228416: Preparing
# c9656524: Preparing
# a9c4357c: Preparing
# c816fb0a: Preparing
# 18ec6a71: Preparing
# 3905242d: Preparing
# 8b80d2bf: Preparing
# e3362d11: Preparing
# 35ef705a: Preparing
# 70b00abb: Preparing
# c816fb0a: Waiting g
# ab65fdde: Preparing
# 18ec6a71: Waiting g
# e418fe5e: Preparing
# e3362d11: Waiting g
# ad7a4f60: Preparing
# ab65fdde: Waiting g
# 70b00abb: Waiting g
# e0b9565e: Waiting g
# 1c774a30: Preparing
# a4b22186: Preparing
# afb09dc3: Preparing
# b5a53aac: Preparing
# c8e5063e: Preparing
# 09e7d9d3: Pushed   2.393GB/2.384GBPushing  232.6MB/2.384GBPushing  243.7MB/2.384GBlatest: digest: sha256:45c5c5e4924737b7f44e7efd595fb16836bb95d44edafba3e899623873108f98 size: 5959
